# %% [markdown]
# # Demonstrating the optDMD and BOP-DMD using a simple example.
#
# Bagging-Optimized Dynamic Mode Decomposition (BOP-DMD) and Optimized Dynamic Mode Decomposition (optDMD)
#
# Citations:
#
# - **optimized Dynamic Mode Decomposition (optDMD)**: Askham, T., & Kutz, J. N. (2018). Variable projection methods for an optimized dynamic mode decomposition. SIAM Journal on Applied Dynamical Systems, 17(1), 380–416. https://doi.org/10.1137/M1124176
#
# - **Bagging, Optimized Dynamic Mode Decomposition (BOP-DMD)**: Sashidhar, D., & Kutz, J. N. (2022). Bagging, optimized dynamic mode decomposition for robust, stable forecasting with spatial and temporal uncertainty quantification. Philosophical Transactions of the Royal Society A: Mathematical, Physical and Engineering Sciences, 380(2229). https://doi.org/10.1098/rsta.2021.0199
#
# ## Details
#
# Both the optDMD and BOP-DMD were previously only matlab implementations. The focus of this notebook is the implementation and testing of crude python translations.
#
# 1) optDMD: Provides an optimized framework for solving the DMD regressions that may come from unevenly spaced time snapshots.
#
# 2) The BOP-DMD takes advantage of this property and solves the DMD using statistical bagging (i.e., randomly selected ensembles) for constructing the DMD.
#
# The advantage of the combined BOP-DMD is: (a) the additional ability to provide uncertainty estimates in the DMD solutions, especially the uncertainty in the spatial modes, (b) the ability to better represent the time dynamics for more complex systems such as those commonly found in geophysics, and (c) robustly solving the DMD for noisy data.
#
# It takes several minutes to run the notebook due to the number of noisy realizations and the size of the ensembles. This version of the BOP-DMD discards certain ensemble members with poor properties, see `BOP-DMD.debug-noisy-data.ipynb` for details.

# %%
# netcdf/numpy/xray/stats
import numpy as np
import xarray as xr
import pandas as pd

# OS interaction
import os
import sys

# import plotting
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.dates import DateFormatter

# %% [markdown]
# ### Quick word on warnings:
#
# The optDMD raises several warnings. They are disabled by the below lines to make the output of the examples cleaner, but there are several points that need to be cleaned up.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# A REALLY STUPID workaround until I make this a package.
get_directories = True
if get_directories:
    notebook_dir = os.getcwd()
    package_dir = os.path.join(notebook_dir, '../..')
    sys.path.append(package_dir)
    from py_optDMD.src import *
    get_directories = False

# %% [markdown]
# ## Format plots

# %%
# %matplotlib inline
# Higher resolution figures within the notebook
# %config InlineBackend.figure_format = 'retina'

# Set the plot style from the seaborn library
sns.set_style("whitegrid")
sns.set_context('paper')

# Tol bright color scheme reordered to put my favorite colors first
tol_bright_reorder = [
    '#4477AA',
    '#CCBB44',
    '#EE6677',
    '#228833',
    '#66CCEE',
    '#AA3377',
    '#BBBBBB'
]
sns.set_palette(sns.color_palette(tol_bright_reorder))

# %% [markdown]
# # "A Simple Example"
#
# The optDMD and the BOP-DMD are both demonstrated using the "Simple Example" from Sashidhar and Kutz (2022). Here data generated from 3 spatial modes are fit. Each mode has time dynamics which are exponential in time.
#
# The specifics of this implementation follow from https://github.com/dsashid/BOP-DMD/blob/main/BOP_DMD_main.m
#
# The results from the python version will be compared to the results from a similar test in matlab.

# %%
# Generate the synthetic data.

# Set up modes in space.
x0 = 0
x1 = 1
nx = 200

# Space component is evenly spaced originally.
xspace = np.linspace(x0,x1,nx)

# Set up the spatial modes
f1 = np.sin(xspace)[:, np.newaxis]
f2 = np.cos(xspace)[:, np.newaxis]
f3 = np.tanh(xspace)[:, np.newaxis]

# Set up the time dynamics.
t0 = 0
t1 = 1
nt = 100
ts = np.linspace(t0,t1,nt)[np.newaxis, :]

# Eigenvalues for each mode
e1 = 1 + 0j
e2 = -2 + 0j
e3 = 0 + 1j
true_eigenvalues = np.array([e1, e2, e3])

# Generate the clean, noiseless dynamics.
xclean = f1.dot(np.exp(e1 * ts)) + f2.dot(np.exp(e2 * ts)) + f3.dot(np.exp(e3 * ts))

# %% [markdown]
# # BOP-DMD

# %% [markdown]
# ## Helper function: build xarray containers for ensemble results
#
# This is not strictly necessary, but xarray is a nice data container that enables easier exploration of ensemble results.

# %%
def build_ensemble_xarray(data, ds_previous=None, num_eigenvalues=3,
                          column_name='ensemble member',
                          concat_dim='cycle', variable_name='eigenvalue'):
    """Convert the results to an xarray Dataset.
    
    Dataset has coordinates of index (a melt of eigenvalue and ensemble member) 
    and cycle (number of ensembles created). The cycle dimension is the dimension
    along which ensembles are stacked in the concatenation.
    """
    
    # Build the eigenvalues dimension
    eigenvalues_coord = [str(k) for k in np.arange(1, num_eigenvalues + 1)]
    
    # Convert to a Pandas dataframe to use the melt function.
    # Build the real component
    df_real = pd.DataFrame(
        data=data.real,
    )

    df_real[variable_name] = eigenvalues_coord
    df_real.columns.names = [column_name]

    df_real = pd.melt(df_real, id_vars=variable_name, value_name='real')

    mi = pd.MultiIndex.from_frame(df_real[[column_name, variable_name]])
    df_real.index = mi
    df_real = df_real.drop([column_name, variable_name], axis=1)

    # Build the imaginary component.
    df_imag = pd.DataFrame(
        data=data.imag,
    )

    df_imag[variable_name] = eigenvalues_coord
    df_imag.columns.names = [column_name]

    df_imag = pd.melt(df_imag, id_vars=variable_name, value_name='imag')

    mi = pd.MultiIndex.from_frame(df_imag[[column_name, variable_name]])
    df_imag.index = mi
    df_imag = df_imag.drop([column_name, variable_name], axis=1)

    # Concatenate the real and imaginary components into a single Dataframe.
    df = pd.concat(
        [df_real, df_imag], axis=1
    )

    # Convert to xarray since this better handles the multidimensional data.
    ds = xr.Dataset.from_dataframe(df)
    if ds_previous is None:
        ds = ds
    else:
        ds = xr.concat([ds_previous, ds], dim=concat_dim)
    return ds

# %% [markdown]
# ## Helper function: pretty evaluation plots
#
# A helper plotting function to simplify making the same plot for each test.

# %%
def eigenvalue_scatterplot(ds, true_eigenvalues, lims=(-3, 3)):
    """Distribution of eigenvalues using a seaborn jointplot.
    
    """
    
    g = sns.jointplot(
        data=ds.to_dataframe(),
        x="real",
        y="imag",
        hue='eigenvalue',
        marginal_kws={'clip': lims},
    )

    g.ax_joint.set_xlim(lims)
    g.ax_joint.set_ylim(lims)
    g.ax_joint.scatter(
        np.real(true_eigenvalues),
        np.imag(true_eigenvalues),
        30,
        color='k',
        marker='o',
        label='True Eigenvalues'
    )
    g.ax_joint.legend()
    g.fig.tight_layout()
    
    return g

# %% [markdown]
# ## Solve
#
# Discard the ensembler member and re-draw when optDMD exits using with: - maximum number of iterations and - using the predicted lambda search.

# %%
# Set the random seed
rng = np.random.default_rng(1)

# Number of time points
n = len(ts)

# Number you want to choose (for each ensemble member?)
p = 50
# Number of noise cycles
num_noise_cycles = 25
# number of cycles for each noise cycle
num_cycles =  100

sigma_array = [1e-1, 1e-2, 1e-3]
# Substantiate the dataset variables.
ds_optdmd = None
ds_entire_ensemble_bopdmd = None
ds_std_bopdmd = None
ds_mean_bopdmd = None

for sigma in sigma_array:
    print('')
    print('======================')
    print('sigma={}\n'.format(sigma))

    # Create containers for the eigenvalues
    e_optDMD = np.zeros((3, num_noise_cycles)).astype(complex)
    e_mean_BOPDMD = np.zeros((3, num_noise_cycles)).astype(complex)
    e_std_BOPDMD = np.zeros((3, num_noise_cycles))


    
    for k in range(num_noise_cycles):
        print(
            'Working on ensemble {} out of {} total ensembles.'.format(
                k + 1,
                num_noise_cycles
            ),
            # end='\r'
        )
        # Create data for noise cycle (add random noise)
        xdata = xclean + sigma * rng.standard_normal(xclean.shape)

        # Create the lambda vector for ensembleDMD cycle
        e_ensembleDMD = np.zeros((3, num_cycles)).astype(complex)

        # Try the DMD -- putting this off until I can figure out how the pydmd and this unknown
        # DMD function relate to each other. Should be straightforward.
        # phi_DMD, lam_DMD, b_DMD, sig_DMD = DMD(xdata(:,1:end-1), xdata(:,2:end), 3);

        # Try the regular optdmd (without bagging)
        w_opt, e_opt, b_opt, _ = optimalDMD.optdmd(xdata, ts, 3, 1)

        # Match the eigenvalues to the true ones using the Munkres algorithm.
        _, indices = bop_dmd.match_vectors(e_opt, true_eigenvalues)
        e_optDMD[:, k] = e_opt[indices]
        
        for j in range(num_cycles):
            # Randomly select time indices for this ensemble member.
            ind = rng.integers(low=0, high=ts.size - 1, size=p)

            # Sort the index to be in ascending order, generating variable length time steps.
            ind = np.sort(ind)

            # Create the subselected data using the sorted indices.
            xdata_cycle = xdata[:, ind]
            ts_ind = ts[:, ind]

            # For very high levels of noise the linear least squares svd solver
            # can fail. Catch those and pass on to the next ensemble member.
            try:
                # Solve optdmd for this ensemble member. Use optDMD modes as initial
                # conditions for BOP-DMD
                w_cycle, e1_cycle, b_cycle, exit_mode = optimalDMD.optdmd(
                    xdata_cycle,ts_ind, 3, 0, alpha_init=e_opt, verbose=False
                )
                
                # Match the eigenvalues to the true ones using the Munkres algorithm.
                _, indices = bop_dmd.match_vectors(e1_cycle, true_eigenvalues)
                
                if exit_mode.lambda_solver == 'predicted' and exit_mode.exit_state == 'maxiter':
                    continue
                    # Assign to the outer container using the correct ordering.
                    e_ensembleDMD[:, j] = np.nan
                else:
                    # Assign to the outer container using the correct ordering.
                    e_ensembleDMD[:, j] = e1_cycle[indices]

            except np.linalg.LinAlgError:
                print('Failed')
                e_ensembleDMD[:, j] = np.complex(np.nan)
                
        print('------------------------------')
        e_mean_BOPDMD[:, k] = np.mean(e_ensembleDMD, 1)
        relerr_e = (
            np.linalg.norm(e_mean_BOPDMD[:, k] - true_eigenvalues, 2)
            / np.linalg.norm(true_eigenvalues, 2)
        )
        print('Mean Eigenvalues Error {:.4f}'.format(relerr_e))
        e_std_BOPDMD[:, k] = np.std(e_ensembleDMD, 1)
        print('std Eigenvalues:')
        print(e_std_BOPDMD[:, k])
        print('------------------------------')
        print()
        
        # Convert the results to an xarray Dataset. Dataset has coordinates of
        # index (a melt of eigenvalue and ensemble member) and cycle (number of
        # ensembles created).
        # ds_entire_ensemble_bopdmd = build_ensemble_xarray(e_ensembleDMD, ds_previous=ds_entire_ensemble_bopdmd)

    ds_optdmd = build_ensemble_xarray(e_optDMD, ds_previous=ds_optdmd, column_name='noise realization', concat_dim='sigma')
    ds_mean_bopdmd = build_ensemble_xarray(
        e_mean_BOPDMD, ds_previous=ds_mean_bopdmd, variable_name='eigenvalue', column_name='noise realization', concat_dim='sigma'
    )
    
    ds_std_bopdmd = build_ensemble_xarray(
        e_std_BOPDMD, ds_previous=ds_std_bopdmd, variable_name='eigenvalue', column_name='noise realization', concat_dim='sigma')

new_names = {dv: dv + '_std' for dv in ds_std_bopdmd.data_vars}
ds_std_bopdmd = ds_std_bopdmd.rename_vars(new_names)
ds_mean_bopdmd.coords['sigma'] = sigma_array
ds_std_bopdmd.coords['sigma'] = sigma_array
ds_bopdmd = xr.merge([ds_mean_bopdmd, ds_std_bopdmd])
ds_optdmd.coords['sigma'] = sigma_array
# Out:
# ======================
# sigma=0.1
#
# Working on ensemble 1 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.3961
# std Eigenvalues:
# [0.3550194  0.19636567 0.32480282]
# ------------------------------
#
# Working on ensemble 2 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.6295
# std Eigenvalues:
# [0.20168199 0.53352832 0.22773063]
# ------------------------------
#
# Working on ensemble 3 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.2443
# std Eigenvalues:
# [0.29944748 0.39614547 0.38276845]
# ------------------------------
#
# Working on ensemble 4 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.3876
# std Eigenvalues:
# [0.44535485 0.48076274 0.22455915]
# ------------------------------
#
# Working on ensemble 5 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.8188
# std Eigenvalues:
# [7.84486133 0.94393538 1.16736087]
# ------------------------------
#
# Working on ensemble 6 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.6782
# std Eigenvalues:
# [0.16263837 0.47096187 0.21085841]
# ------------------------------
#
# Working on ensemble 7 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.6784
# std Eigenvalues:
# [3.20448086 2.53458113 0.68289204]
# ------------------------------
#
# Working on ensemble 8 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.4231
# std Eigenvalues:
# [0.22065197 0.20329135 0.18045515]
# ------------------------------
#
# Working on ensemble 9 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.3581
# std Eigenvalues:
# [0.24261799 0.16765415 0.20131551]
# ------------------------------
#
# Working on ensemble 10 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.6614
# std Eigenvalues:
# [0.35272055 0.54138121 0.39070176]
# ------------------------------
#
# Working on ensemble 11 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.7830
# std Eigenvalues:
# [7.49057987 0.89944272 0.42533271]
# ------------------------------
#
# Working on ensemble 12 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.6440
# std Eigenvalues:
# [0.11848164 0.34360213 0.14443331]
# ------------------------------
#
# Working on ensemble 13 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.4839
# std Eigenvalues:
# [0.70015846 0.62349015 0.20265704]
# ------------------------------
#
# Working on ensemble 14 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.5015
# std Eigenvalues:
# [0.35331401 0.32889863 0.60493435]
# ------------------------------
#
# Working on ensemble 15 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.3953
# std Eigenvalues:
# [4.31997574 0.51858437 0.26568242]
# ------------------------------
#
# Working on ensemble 16 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.3528
# std Eigenvalues:
# [0.16822126 0.13504402 0.15414038]
# ------------------------------
#
# Working on ensemble 17 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.2612
# std Eigenvalues:
# [0.18297004 0.18088767 0.37461772]
# ------------------------------
#
# Working on ensemble 18 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.4818
# std Eigenvalues:
# [5.29641859 0.96948966 0.32952275]
# ------------------------------
#
# Working on ensemble 19 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.9524
# std Eigenvalues:
# [8.44394476 1.06459656 0.37123084]
# ------------------------------
#
# Working on ensemble 20 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.9422
# std Eigenvalues:
# [ 0.55798063  8.76773859 19.62966907]
# ------------------------------
#
# Working on ensemble 21 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.3260
# std Eigenvalues:
# [0.21698352 0.38830076 0.23793742]
# ------------------------------
#
# Working on ensemble 22 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.6277
# std Eigenvalues:
# [0.12991055 0.38705504 0.1589494 ]
# ------------------------------
#
# Working on ensemble 23 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.3690
# std Eigenvalues:
# [0.46857662 0.31664007 0.48670479]
# ------------------------------
#
# Working on ensemble 24 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 1.1739
# std Eigenvalues:
# [ 0.45654493  0.77056787 31.12294291]
# ------------------------------
#
# Working on ensemble 25 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.9115
# std Eigenvalues:
# [4.49814202 0.26721714 0.07952756]
# ------------------------------
#
#
# ======================
# sigma=0.01
#
# Working on ensemble 1 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0432
# std Eigenvalues:
# [0.17739614 0.19963194 0.51819527]
# ------------------------------
#
# Working on ensemble 2 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1838
# std Eigenvalues:
# [0.11541948 0.00909873 0.07126777]
# ------------------------------
#
# Working on ensemble 3 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1197
# std Eigenvalues:
# [0.1511406  0.03912373 0.34664461]
# ------------------------------
#
# Working on ensemble 4 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0390
# std Eigenvalues:
# [0.2006562  0.03107325 0.45582411]
# ------------------------------
#
# Working on ensemble 5 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0505
# std Eigenvalues:
# [0.22709796 0.19901794 0.56173969]
# ------------------------------
#
# Working on ensemble 6 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1029
# std Eigenvalues:
# [0.16203727 0.03021007 0.42971778]
# ------------------------------
#
# Working on ensemble 7 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0597
# std Eigenvalues:
# [0.22101151 0.20193887 0.3771252 ]
# ------------------------------
#
# Working on ensemble 8 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1737
# std Eigenvalues:
# [0.00838256 0.00272174 0.01422946]
# ------------------------------
#
# Working on ensemble 9 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0219
# std Eigenvalues:
# [0.13873234 0.03639831 0.36969685]
# ------------------------------
#
# Working on ensemble 10 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0620
# std Eigenvalues:
# [0.1615261  0.02651524 0.38414063]
# ------------------------------
#
# Working on ensemble 11 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.2037
# std Eigenvalues:
# [5.70845522e-14 6.97713150e-14 4.91946435e-14]
# ------------------------------
#
# Working on ensemble 12 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0493
# std Eigenvalues:
# [0.15514944 0.02174797 0.4149935 ]
# ------------------------------
#
# Working on ensemble 13 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1851
# std Eigenvalues:
# [0.00422593 0.00585821 0.01937102]
# ------------------------------
#
# Working on ensemble 14 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0536
# std Eigenvalues:
# [0.15108148 0.02744674 0.31480676]
# ------------------------------
#
# Working on ensemble 15 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1078
# std Eigenvalues:
# [0.31101786 0.20080015 0.47708586]
# ------------------------------
#
# Working on ensemble 16 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0331
# std Eigenvalues:
# [0.20340026 0.19972049 0.42161598]
# ------------------------------
#
# Working on ensemble 17 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0446
# std Eigenvalues:
# [0.14947054 0.03476993 0.42882266]
# ------------------------------
#
# Working on ensemble 18 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1081
# std Eigenvalues:
# [0.15468265 0.04165631 0.43100462]
# ------------------------------
#
# Working on ensemble 19 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1227
# std Eigenvalues:
# [0.18910178 0.03097167 0.53099962]
# ------------------------------
#
# Working on ensemble 20 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1633
# std Eigenvalues:
# [0.17434877 0.20097728 0.53797097]
# ------------------------------
#
# Working on ensemble 21 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1191
# std Eigenvalues:
# [0.17345607 0.03224348 0.39282379]
# ------------------------------
#
# Working on ensemble 22 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0230
# std Eigenvalues:
# [0.20199634 0.20454987 0.45560551]
# ------------------------------
#
# Working on ensemble 23 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0393
# std Eigenvalues:
# [0.16098652 0.0259085  0.41990681]
# ------------------------------
#
# Working on ensemble 24 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0242
# std Eigenvalues:
# [0.19545463 0.20311652 0.40349326]
# ------------------------------
#
# Working on ensemble 25 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0440
# std Eigenvalues:
# [0.2095911  0.03234802 0.45708011]
# ------------------------------
#
#
# ======================
# sigma=0.001
#
# Working on ensemble 1 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0010
# std Eigenvalues:
# [0.01057015 0.00273176 0.02629156]
# ------------------------------
#
# Working on ensemble 2 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0013
# std Eigenvalues:
# [0.00909379 0.00326779 0.02198072]
# ------------------------------
#
# Working on ensemble 3 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0026
# std Eigenvalues:
# [0.00945247 0.00209402 0.02384682]
# ------------------------------
#
# Working on ensemble 4 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0046
# std Eigenvalues:
# [0.01287222 0.00249957 0.03020465]
# ------------------------------
#
# Working on ensemble 5 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0028
# std Eigenvalues:
# [0.01350458 0.00209928 0.03311844]
# ------------------------------
#
# Working on ensemble 6 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0072
# std Eigenvalues:
# [0.01160257 0.00237119 0.02808626]
# ------------------------------
#
# Working on ensemble 7 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0036
# std Eigenvalues:
# [0.00900228 0.00242012 0.02246195]
# ------------------------------
#
# Working on ensemble 8 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1704
# std Eigenvalues:
# [0.00976785 0.00121779 0.01973704]
# ------------------------------
#
# Working on ensemble 9 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0066
# std Eigenvalues:
# [0.00947821 0.00290748 0.0237181 ]
# ------------------------------
#
# Working on ensemble 10 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0044
# std Eigenvalues:
# [0.01012677 0.00284146 0.02601736]
# ------------------------------
#
# Working on ensemble 11 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0051
# std Eigenvalues:
# [0.00953474 0.00225721 0.02390747]
# ------------------------------
#
# Working on ensemble 12 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0049
# std Eigenvalues:
# [0.01269378 0.00290822 0.03199735]
# ------------------------------
#
# Working on ensemble 13 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0041
# std Eigenvalues:
# [0.01178626 0.00230733 0.02904339]
# ------------------------------
#
# Working on ensemble 14 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0080
# std Eigenvalues:
# [0.0104162  0.00261598 0.02590796]
# ------------------------------
#
# Working on ensemble 15 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0179
# std Eigenvalues:
# [0.0107172  0.00274086 0.02649261]
# ------------------------------
#
# Working on ensemble 16 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0035
# std Eigenvalues:
# [0.0098916  0.00296126 0.02447724]
# ------------------------------
#
# Working on ensemble 17 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0023
# std Eigenvalues:
# [0.00966456 0.00199907 0.02340961]
# ------------------------------
#
# Working on ensemble 18 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0063
# std Eigenvalues:
# [0.01039665 0.00223768 0.02569086]
# ------------------------------
#
# Working on ensemble 19 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0010
# std Eigenvalues:
# [0.0114291  0.00270916 0.02851995]
# ------------------------------
#
# Working on ensemble 20 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0116
# std Eigenvalues:
# [0.00893958 0.00212999 0.02281368]
# ------------------------------
#
# Working on ensemble 21 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0034
# std Eigenvalues:
# [0.01132821 0.00221444 0.02716163]
# ------------------------------
#
# Working on ensemble 22 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.1818
# std Eigenvalues:
# [0.02853095 0.00242063 0.04365166]
# ------------------------------
#
# Working on ensemble 23 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0030
# std Eigenvalues:
# [0.00989741 0.00248827 0.02470925]
# ------------------------------
#
# Working on ensemble 24 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0082
# std Eigenvalues:
# [0.01067072 0.00254245 0.02571751]
# ------------------------------
#
# Working on ensemble 25 out of 25 total ensembles.
# ------------------------------
# Mean Eigenvalues Error 0.0110
# std Eigenvalues:
# [0.00971688 0.00315352 0.02468055]
# ------------------------------

# %% [markdown]
# ### Visualize the results: Eigenvalues
#
# #### BOP-DMD

# %%
# Distribution plots for the BOP-DMD and optDMD eigenvalues.

for sigma in ds_bopdmd.sigma:
    
    g = eigenvalue_scatterplot(ds_bopdmd.sel(sigma=sigma), true_eigenvalues, lims=(-3, 3))
    g.fig.suptitle("BOP-DMD mean eigenvalue distribution, sigma={}".format(sigma.values))

    for nk, k in enumerate(ds_bopdmd.eigenvalue):
        ds = ds_bopdmd.sel(eigenvalue=k, sigma=sigma)
        ds_mean = ds.mean(dim='noise realization')
        
        # Errorbars for each noise realization across the entire ensemble
        g.ax_joint.errorbar(
            ds['real'],
            ds['imag'],
            xerr=ds['real_std'],
            yerr=ds['real_std'],
            fmt='none',
            color=tol_bright_reorder[nk],
            zorder=0,
            alpha=0.5,
        )
        
        # Circle of the total eigenvalue uncertainty across all realizations
        e_std_circle = plt.Circle(
            (ds_mean['real'], ds_mean['imag']),
            ds_mean.real_std.values,
            color=tol_bright_reorder[nk],
            alpha=0.2
        )
        g.ax_joint.add_patch(e_std_circle)
        g.ax_joint.scatter(
            ds_mean['real'],
            ds_mean['imag'],
            50,
            color=tol_bright_reorder[nk],
            marker='s',
            edgecolor='k',
            label='{}, BOP-DMD mean'.format(k.values)
        )

        ds = ds_optdmd.sel(eigenvalue=k, sigma=sigma).mean(dim='noise realization')
        g.ax_joint.scatter(
            ds['real'],
            ds['imag'],
            50,
            color=tol_bright_reorder[nk],
            marker='^',
            edgecolor='k',
            label='{}, optDMD mean'.format(k.values)
        )
        g.ax_joint.legend()
    g.fig.tight_layout()
    g.fig.savefig('python_BOP-DMD.sigma={}.png'.format(sigma.values))

# %% [markdown]
# Circles are centered on the mean BOP-DMD eigenvalue with a radius equal to the standard deviation across noisy realizations.
#
# #### optDMD for comparison

# %%
for sigma in ds_bopdmd.sigma:
    g = eigenvalue_scatterplot(ds_optdmd.sel(sigma=sigma), true_eigenvalues, lims=(-3, 3))
    for nk, k in enumerate(ds_bopdmd.eigenvalue):
        ds = ds_optdmd.sel(eigenvalue=k, sigma=sigma).mean(dim='noise realization')
        g.ax_joint.scatter(
            ds['real'],
            ds['imag'],
            50,
            color=tol_bright_reorder[nk],
            marker='^',
            edgecolor='k',
            label='{}, optDMD mean'.format(k.values)
        )

    g.fig.suptitle("optDMD eigenvalue distribution, sigma={}".format(sigma.values))
